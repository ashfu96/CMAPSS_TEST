# %% [markdown]
# <a href="https://colab.research.google.com/github/ashfu96/CMAPSS_TEST/blob/main/Dashboard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # test 1

# %%
#import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# %%
#url da github
url_TRAIN = "https://raw.githubusercontent.com/ashfu96/CMAPSS_TEST/main/train_FD001.txt"
url_TEST = "https://raw.githubusercontent.com/ashfu96/CMAPSS_TEST/main/test_FD001.txt"
url_RUL= "https://raw.githubusercontent.com/ashfu96/CMAPSS_TEST/main/RUL_FD001.txt"

df_train = pd.read_csv(url_TRAIN, sep=" ", header=None)
df_test = pd.read_csv(url_TEST, sep=" ", header=None)
df_rul = pd.read_csv(url_RUL, sep=" ", header=None)

# %%
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Modifiche apportate al dataset

# %%
# Rimozione di colonne con NaN value
df_train.drop(columns=[26,27], axis=1, inplace=True)
df_test.drop(columns=[26,27], axis=1, inplace=True)
df_rul.drop(columns=[1], axis=1, inplace=True)

# %%
# Ridenominazione delle colonne con le label
columns_train = ['unit_ID','time_in_cycles','setting_1', 'setting_2','setting_3','T2','T24','T30','T50','P2','P15','P30','Nf',
           'Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32' ]

df_train.columns = columns_train
df_test.columns = columns_train

df_train.columns
# Out:
# Index(['unit_ID', 'time_in_cycles', 'setting_1', 'setting_2', 'setting_3',
#        'T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr',
#        'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd',
#        'PCNfR_dmd', 'W31', 'W32'],
#       dtype='object')

# %% [markdown]
# ## Plot test 1

# %% [markdown]
# ```
# # sensor_list = ['T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr',
# #        'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd',
# #        'PCNfR_dmd', 'W31', 'W32']
# ```

# %%
# Creazione della barra laterale per la selezione del sensore

df = df_train.copy()
df = df.iloc[:, 5:]
sensor_list = df.columns.tolist()
print(sensor_list)

# sidebar per selezione del sensore
sensor = st.sidebar.selectbox('Seleziona il sensore', sensor_list)


# Creazione del grafico dell'andamento del sensore in base al tempo
st.write(f'Andamento del sensore {sensor}')
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(df_train['time_in_cycles'], df_train[sensor])
ax.set_xlabel('Tempo')
ax.set_ylabel('Valore del sensore')
st.pyplot(fig)

# %% [markdown]
# # test 2

# %% [markdown]
# prima pagina vedere tutti i unit_id con rul inferiore ad una soglia

# %% [markdown]
# ## dataset

# %%
#import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# %%
#url da github
url_TRAIN = "https://raw.githubusercontent.com/ashfu96/CMAPSS_TEST/main/train_FD001.txt"
url_TEST = "https://raw.githubusercontent.com/ashfu96/CMAPSS_TEST/main/test_FD001.txt"
url_RUL= "https://raw.githubusercontent.com/ashfu96/CMAPSS_TEST/main/RUL_FD001.txt"

df_train = pd.read_csv(url_TRAIN, sep=" ", header=None)
df_test = pd.read_csv(url_TEST, sep=" ", header=None)
df_rul = pd.read_csv(url_RUL, sep=" ", header=None)

# %% [markdown]
# ## PREPROCESSING
# Modifiche apportate al dataset

# %%
# Rimozione di colonne con NaN value
df_train.drop(columns=[26,27], axis=1, inplace=True)
df_test.drop(columns=[26,27], axis=1, inplace=True)
df_rul.drop(columns=[1], axis=1, inplace=True)

# %%
# Ridenominazione delle colonne con le label
columns_train = ['unit_ID','time_in_cycles','setting_1', 'setting_2','setting_3','T2','T24','T30','T50','P2','P15','P30','Nf',
           'Nc','epr','Ps30','phi','NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32' ]

df_train.columns = columns_train
df_test.columns = columns_train

#df_train.columns

# %%
# rimozione sensori con standar deviation = 0 
####TRAIN###
train = df_train.loc[:, df_train.std() != 0]

#train.columns

# %%
train.columns
# Out:
# Index(['unit_ID', 'time_in_cycles', 'setting_1', 'setting_2', 'T24', 'T30',
#        'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'Ps30', 'phi', 'NRf', 'NRc',
#        'BPR', 'farB', 'htBleed', 'W31', 'W32'],
#       dtype='object')

# %%
# rimozione sensori con standar deviation = 0 
####TEST###

col = train.columns.tolist() 
test = df_test.loc[:, col]

test.columns
# Out:
# Index(['unit_ID', 'time_in_cycles', 'setting_1', 'setting_2', 'T24', 'T30',
#        'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'Ps30', 'phi', 'NRf', 'NRc',
#        'BPR', 'farB', 'htBleed', 'W31', 'W32'],
#       dtype='object')

# %% [markdown]
# alla fine del preprocessing, i dataframe soggetti a modifica si chiamano TRAIN E TEST (no df...)

# %% [markdown]
# ## plot solo sensori

# %% [markdown]
# ```
# # sensor_list = ['T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr',
# #         'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd',
# #         'PCNfR_dmd', 'W31', 'W32']
# ```

# %%
# rimozione setting, lasciando solo unit_ID, e sensori non nulli
##### TRAIN #####

TRAIN = train.copy()
TRAIN = TRAIN.drop(TRAIN.iloc[:, 1:4], axis=1)

TRAIN.head(50)
# Out:
#     unit_ID     T24      T30      T50     P2    P15     P30       Nf       Nc  \
# 0         1  641.82  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19
# 1         1  642.15  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07
# 2         1  642.35  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94
# 3         1  642.35  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48
# 4         1  642.37  1582.85  1406.22  14.62  21.61  554.00  2388.06  9055.15
# 5         1  642.10  1584.47  1398.37  14.62  21.61  554.67  2388.02  9049.68
# 6         1  642.48  1592.32  1397.77  14.62  21.61  554.34  2388.02  9059.13
# 7         1  642.56  1582.96  1400.97  14.62  21.61  553.85  2388.00  9040.80
# 8         1  642.12  1590.98  1394.80  14.62  21.61  553.69  2388.05  9046.46
# 9         1  641.71  1591.24  1400.46  14.62  21.61  553.59  2388.05  9051.70
# 10        1  642.28  1581.75  1400.64  14.62  21.61  554.54  2388.05  9049.61
# ...

# %%
# rimozione setting, lasciando solo unit_ID, e sensori non nulli
##### TEST #####

TEST = test.copy()
TEST = TEST.drop(TEST.iloc[:, 1:4], axis=1)

TEST.head(50)
# Out:
#     unit_ID     T24      T30      T50     P2    P15     P30       Nf       Nc  \
# 0         1  643.02  1585.29  1398.21  14.62  21.61  553.90  2388.04  9050.17
# 1         1  641.71  1588.45  1395.42  14.62  21.61  554.85  2388.01  9054.42
# 2         1  642.46  1586.94  1401.34  14.62  21.61  554.11  2388.05  9056.96
# 3         1  642.44  1584.12  1406.42  14.62  21.61  554.07  2388.03  9045.29
# 4         1  642.51  1587.19  1401.92  14.62  21.61  554.16  2388.01  9044.55
# 5         1  642.11  1579.12  1395.13  14.62  21.61  554.22  2388.00  9050.96
# 6         1  642.11  1583.34  1404.84  14.62  21.61  553.89  2388.05  9051.39
# 7         1  642.54  1580.89  1400.89  14.62  21.61  553.59  2388.05  9052.86
# 8         1  641.88  1593.29  1412.28  14.62  21.61  554.49  2388.06  9048.55
# 9         1  642.07  1585.25  1398.64  14.62  21.61  554.28  2388.04  9051.95
# 10        1  642.04  1581.03  1403.83  14.62  21.61  554.69  2388.04  9051.67
# ...

# %% [markdown]
# chatgpt

# %%
#!pip install streamlit

# %%
import streamlit as st

# %%
def plot_sensor_data(df, unit_ID):
    """
    Crea un plot con l'andamento dei sensori per l'unit_ID selezionata.
    
    Args:
    - df (pandas.DataFrame): il dataframe contenente i dati dei sensori
    - unit_ID (int): l'unit_ID selezionata
    
    Returns:
    - None
    """
    # Seleziona i dati per l'unit_ID selezionata
    data = TEST[TEST['unit_ID'] == unit_ID]

    # Plotta l'andamento dei sensori per l'unit_ID selezionata
    data.plot(x='tempo', y=['T2', 'T24', 'T30', 'T50', 'P2', 'P15', 'P30', 'Nf', 'Nc', 'epr',
         'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd',
         'PCNfR_dmd', 'W31', 'W32'])
    plt.title(f'Andamento sensori per unit_ID={unit_ID}')

    # Mostra il plot nell'applicazione Streamlit
    st.pyplot()

# Esempio di utilizzo dell'applicazione Streamlit
#if __name__ == '__main__':
    # Carica il dataset
    #df = pd.read_csv("nome_file.csv")

    # Crea l'applicazione Streamlit
    st.title("Visualizzazione dati sensori per unit_ID")
    
    # Aggiungi una sidebar per selezionare l'unit_ID
    unit_ID = st.sidebar.selectbox("Seleziona l'unit_ID", TEST['unit_ID'].unique())

    # Mostra il plot dell'andamento dei sensori per l'unit_ID selezionata
    plot_sensor_data(TEST, unit_ID)
